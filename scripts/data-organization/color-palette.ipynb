# %%
import seaborn as sns
import pandas as pd
import json
import random

data = json.load(open("../../data/trade_top_imports.json", "r"))
countryColorPalette = sns.color_palette('husl', len(data["countries"]))
sns.palplot(countryColorPalette)
json.dump({"colors": countryColorPalette.as_hex()}, open("../../data/country_colors.json", "w"))
